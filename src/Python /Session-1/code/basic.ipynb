# %% [markdown]
# # This is a header

# %%
x = 5 

print (x)
# Out:
# 5
# ERROR! Session/line number was not unique in database. History logging moved to new session 9

# %%
# this is a comment

x= "Hisham"

'''
comment block   

'''
print (type(x))
# Out:
# <class 'str'>

# %%
name = "Hisham"
age = 25
print ("My name is {0}  and I am {1} years old".format(name, age))
print (f"My name is {name} and I am {age} years old")
# Out:
# My name is Hisham , and I am 25 years old
# My name is Hisham and I am 25 years old

# %%
name = "Mohamed Hisham"
age = 25
output = f"My name is {name} and I am {age} years old"
print (output)
# Out:
# My name is Mohamed Hisham and I am 25 years old

# %%
name  = "Depi for Machine Learning"
print (type(name))
print (name[3])
print (name[-3])
# Out:
# <class 'str'>
# i
# i

# %%
print (name[0:4])
print(name[0:4:2])
print(name[-6:-1:1])
# Out:
# Depi
# Dp
# arnin

# %%
x= 5
y =10

x
y

print (x)

y
# Out:
# 5
# 10

# %%
name = input("Enter your name: ")
print ("Hello " + name)
# Out:
# Hello Hisham

# %%
name = "Depi for Machine Learning"
print (name.upper())
print (name.lower())   
print (name.replace("for", "in"))
print (name.title())
print (name.split(" "))
print (name.capitalize())
# Out:
# DEPI FOR MACHINE LEARNING
# depi for machine learning
# Depi in Machine Learning
# Depi For Machine Learning
# ['Depi', 'for', 'Machine', 'Learning']
# Depi for machine learning

# %%
tokens = ["Depi", "for", "Machine", "Learning"]
print (" ".join(tokens))
# Out:
# Depi for Machine Learning

# %%
name = "Depi for Machine Learning"
print(name.startswith("Depi"))
# Out:
# True

# %%
print ("Hello,  \n World!")
# Out:
# Hello,
#  World!

# %%
print ("this is escaped character \"Hisham\" ")
# Out:
# this is escaped character "Hisham"
